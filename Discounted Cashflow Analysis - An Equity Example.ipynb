# %% [markdown]
# ## Overview
# <font color='blue'>
#
# ### - Introduction to Refinitiv Company Fundamentals (RCF) & Estimates Dataset
#
# ### - Conduct Discounted Cashflow (DCF) type instrinsic valuation
#
# ### - Scale to calculate DCF for peers to provide a relative value overlay
#
# ### - Use unsupervised ML routines to generate classification groupings for our data</font>

# %% [markdown]
# ##  Refinitiv Company Fundamental (RCF) data
# <font color='blue'>
#
# ### - New Strategic Content Set (see RCFLAND for much more info)
#
# ### - Both company specific (ASR) and standardised data to enhance comparison internationally, via different accounting standards and across industries
#
# ### - RCF contains 60% more content than previous Refinitiv Fundamentals content set
#
# ### - IS, CF, BS statements available via one field call - vastly improved workflow</font>

# %%
import refinitiv.dataplatform.eikon as ek
import numpy as np
from numpy import where
from numpy import unique
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.linear_model import LinearRegression
import pylab as plt
import warnings
import configparser
cfg = configparser.ConfigParser()
cfg.read('rdp.cfg',encoding='utf-8')
# %matplotlib inline
plt.style.use("seaborn")
warnings.filterwarnings("ignore")
ek.set_app_key(cfg['eikon']['app_key']) # or just put your appkey in here

# %% [markdown]
# <font color='blue'>
#
# ### - 5 Industry Templates - Industrial, Property, Bank, Insurance, Other FInancial
#
# ### - Standardised or As Reported (ASR)
#
# ### - One API call to get all fields for a particular statement - plenty of parameters so check DIB for more available parameters
#
# ### Income Statement </font>

# %%
df, err =ek.get_data(['VOD.L'],['TR.F.IncomeStatement.fieldname','TR.F.IncomeStatement.fielddescription','TR.F.IncomeStatement'], 
            parameters = {'Period': 'FY0','reportingState':'Rsdt', 'curn':'Native', 'Scale':'6','SORTA':'LISeq'})
df
# Out:
#     Instrument                               Name  \
# 0        VOD.L                  TR.F.RevGoodsSrvc
# 1        VOD.L  TR.F.SalesOfGoodsSrvcNetUnclassif
# 2        VOD.L          TR.F.RevBizRelActivOthTot
# 3        VOD.L                    TR.F.TotRevenue
# 4        VOD.L                   TR.F.CostOfOpRev
# ..         ...                                ...
# 141      VOD.L        TR.F.COGSInclOpMaintUtilTot
# 142      VOD.L                  TR.F.COGSExclDepr
# 143      VOD.L                      TR.F.IntrExpn
# 144      VOD.L                        TR.F.OpExpn
# 145      VOD.L                    TR.F.SGAExclRnD
#
#                                            Description  \
# 0    Revenue from Goods & Services [SNTS] represent...
# 1    Sales of Goods & Services - Net - Unclassified...
# 2    Revenue from Business-Related Activities - Oth...
# 3    Revenue from Business Activities - Total [STLR...
# 4    Cost of Operating Revenue [SCOR] represents th...
# ..                                                 ...
# 141  Cost of Revenue including Operation & Maintena...
# 142  Cost of Revenues excluding Depreciation [SCOGX...
# 143  Interest Expense [SINTEX] represents Net inter...
# 144  Operating Expenses [SOPEX] represents the tota...
# 145  Selling, General & Administrative Expenses exc...
#
#      STD Income Statement All
# 0                     37141.0
# 1                     37141.0
# 2                      6668.0
# 3                     43809.0
# 4                     30086.0
# ..                        ...
# 141                   30086.0
# 142                   30086.0
# 143                     837.0
# 144                   38698.0
# 145                    9536.0
#
# [146 rows x 4 columns]

# %% [markdown]
# <font color='blue'>
#
# ### Cashflow Statement</font>

# %%
df1, err =ek.get_data(['VOD.L'],['TR.F.CashflowStatement.fieldname','TR.F.CashflowStatement.fielddescription','TR.F.CashflowStatement'],
            parameters = {'Period': 'FY0','reportingState':'Rsdt', 'curn':'Native', 'Scale':'6','SORTA':'LISeq'})
df1
# Out:
#    Instrument                          Name  \
# 0       VOD.L   TR.F.ProfLossStartingLineCF
# 1       VOD.L  TR.F.NonCashItemsReconcAdjCF
# 2       VOD.L      TR.F.DiscOpsGLNetOfTaxCF
# 3       VOD.L     TR.F.EqIncLossInNetEarnCF
# 4       VOD.L             TR.F.IncTaxExpnCF
# ..        ...                           ...
# 69      VOD.L       TR.F.ComStockBuybackNet
# 70      VOD.L          TR.F.DeprDeplAmortCF
# 71      VOD.L         TR.F.FreeCashFlowToEq
# 72      VOD.L                     TR.F.FOCF
# 73      VOD.L              TR.F.LeveredFOCF
#
#                                           Description  STD Cash Flow All
# 0   Profit/(Loss) - Starting Line - Cash Flow [SPL...                536
# 1   Non-cash Items & Reconciliation Adjustments - ...              17915
# 2   Discontinued Operations - Gain/(Loss) - Net of...                  0
# 3   Equity Income/(Loss) in Net Earnings - Cash Fl...               -342
# 4   Income Tax Expense - Cash Flow - to Reconcile ...               3864
# ..                                                ...                ...
# 69  Common Stock Buyback - Net [SCSBN] represents ...                 57
# 70  Depreciation, Depletion & Amortization - Cash ...              14101
# 71  Free Cash Flow to Equity [SFCFE] represents th...              -3862
# 72  Free Cash Flow Net of Dividends [SFCFO] repres...               4297
# 73  Free Cash Flow [SFCFL] represents the differen...               6724
#
# [74 rows x 4 columns]

# %% [markdown]
# <font color='blue'>
#
# ### Balance Sheet</font>

# %%
df2, err =ek.get_data(['VOD.L'],['TR.F.BalanceSheet.fieldname','TR.F.BalanceSheet.fielddescription','TR.F.BalanceSheet'],
            parameters = {'Period': 'FY0','reportingState':'Rsdt', 'curn':'Native', 'Scale':'6','SORTA':'LISeq'})
df2
# Out:
#     Instrument                              Name  \
# 0        VOD.L                  TR.F.CashSTInvst
# 1        VOD.L                TR.F.CashCashEquiv
# 2        VOD.L                   TR.F.STInvstTot
# 3        VOD.L         TR.F.DerivFinInstrHedgeST
# 4        VOD.L              TR.F.LoansRcvblNetST
# ..         ...                               ...
# 171      VOD.L            TR.F.TotFixedAssetsNet
# 172      VOD.L                 TR.F.UnearnRevTot
# 173      VOD.L                       TR.F.WkgCap
# 174      VOD.L                TR.F.WkgCapNonCash
# 175      VOD.L  TR.F.WkgCapExclOthCurrAssetsLiab
#
#                                            Description  STD Balance Sheet All
# 0    Cash & Short Term Investments [SCSI] refers to...                14980.0
# 1    Cash & Cash Equivalents [SCAE] represents shor...                 5821.0
# 2    Short-Term Investments - Total [SSTI] represen...                 9159.0
# 3    Derivative Financial Instruments - Hedging - S...                  239.0
# 4    Loans & Receivables - Net - Short-Term [SCLR] ...                10036.0
# ..                                                 ...                    ...
# 171  Total Fixed Assets - Net [STNCA] is calculated...                91542.0
# 172  Unearned Revenue - Total [SUREV] represents th...                 1715.0
# 173  Working Capital [SWCAP] represents a differenc...                -1698.0
# 174  Working Capital - Non-Cash [SNCWC] represents ...               -16678.0
# 175  Working Capital excluding Other Current Assets...                 6570.0
#
# [176 rows x 4 columns]

# %% [markdown]
# ## Estimates Data
# <font color='blue'>
#
# ### - Eikon/WS carries over 260+ types of estimate related to company financials - lets look at some of these briefly
#
# ### Company Estimates
#
# ### - Company releases forward looking guidance for quarterly, interim or full year(s) ahead
#
# ### - Specify as much detail as you want, includes transcripts of investor meetings, press releases, speaker who said it etc.
#
# ### - Both actual value based updates and contextual updates sourced</font>

# %%
df3,err = ek.get_data('VOD.L',['TR.GuidanceDate','TR.GuidanceMeasure','TR.EstGuidHighValue','TR.EstGuidLowValue','TR.GuidanceText','TR.GuidanceDocType'],
                   {'Period':'FY1','GuidMeasure':'REV,EBIT,EBITDA','GuidDataBasis':'VAL'})
 
df3
# Out:
#   Instrument       Activation Date Guidance Measure  Guidance High Value  \
# 0      VOD.L  2021-02-15T07:00:06Z          Revenue          15400000000
# 1      VOD.L  2021-02-24T07:00:05Z          Revenue                 <NA>
# 2      VOD.L  2020-05-12T07:00:03Z             EBIT                 <NA>
# 3      VOD.L  2021-02-15T07:00:06Z           EBITDA                 <NA>
#
#    Guidance Low Value                                      Guidance Text  \
# 0         15000000000  Consolidated Vantage Towers FY21 Pro forma(7) ...
# 1                <NA>  (excluding pass through revenue) compound annu...
# 2                <NA>  Moreover, we expect to deliver a net reduction...
# 3                <NA>  Adj. EBITDAaL €520-530m High 50s percentage ma...
#
#     The Doc Type
# 0  Press Release
# 1  Press Release
# 2  Press Release
# 3  Press Release

# %% [markdown]
# <font color='blue'>
#
# ### Analyst Estimates
#
# ### - Companies depending or their size are followed by sell-side analysts who make forecasts and some sort of recommendation and price target
#
# ### - Large companies where there are many analysts following - likely to be more updates - good as more recent events captured
#
# ### - List of forecasted items has grown over the decades to include CF and even BS items - but not all analysts may provide detail
#
# ### - Expanded coverage of industry specific meterics - see chart below:
#
# ![image.png](attachment:image.png)
#
# ### - So lets have a look at how we can get individual analyst estimates for a stock - here we just look at Revenue.</font>

# %%
df4, err =ek.get_data(['VOD.L'],['TR.RevenueEstValue(Period=FY1).date',
                                 'TR.RevenueEstValue(Period=FY1).brokername',
                                 'TR.RevenueEstValue(Period=FY1).analystname',
                                 'TR.RevenueEstValue(Period=FY1).analystcode',
                                 'TR.RevenueEstValue(Period=FY1)'])
                      
df4
# Out:
#    Instrument                  Date                    Broker Name  \
# 0       VOD.L  2021-05-19T04:02:00Z         CREDIT SUISSE - EUROPE
# 1       VOD.L  2021-05-27T19:35:00Z                  GOLDMAN SACHS
# 2       VOD.L  2021-05-07T05:10:00Z                  DEUTSCHE BANK
# 3       VOD.L  2021-04-28T13:45:00Z       REDBURN (EUROPE) LIMITED
# 4       VOD.L  2021-02-03T14:00:00Z                       JPMORGAN
# 5       VOD.L  2021-06-09T05:11:00Z  LANDESBANK BADEN-WUERTTEMBERG
# 6       VOD.L  2021-04-01T13:18:00Z               SOCIETE GENERALE
# 7       VOD.L  2020-11-10T17:37:00Z        ESN/BANCA AKROS (ITALY)
# 8       VOD.L  2021-02-22T05:56:00Z                      BERENBERG
# 9       VOD.L  2021-02-23T01:48:00Z              MORNINGSTAR, INC.
# 10      VOD.L  2021-05-18T10:30:00Z                            UBS
# 11      VOD.L  2021-06-09T17:42:00Z                           HSBC
# 12      VOD.L  2021-05-19T20:26:00Z           NEXTGEN RESEARCH LTD
# 13      VOD.L  2020-10-21T09:44:00Z                        DZ BANK
# 14      VOD.L  2021-04-08T08:08:00Z                      JEFFERIES
# 15      VOD.L  2021-05-19T05:07:00Z                       BARCLAYS
# 16      VOD.L  2020-07-29T18:47:00Z                       ODDO BHF
# 17      VOD.L  2021-05-18T18:13:00Z           BOFA GLOBAL RESEARCH
# 18      VOD.L  2021-02-04T06:31:00Z               KEPLER CHEUVREUX
# 19      VOD.L  2021-01-18T08:58:00Z                 ARETE RESEARCH
# 20      VOD.L  2021-03-25T06:13:00Z                 MORGAN STANLEY
# 21      VOD.L  2021-05-24T07:11:00Z               NUMIS SECURITIES
# 22      VOD.L  2021-05-19T09:01:00Z              EXANE BNP PARIBAS
#
#                  Analyst Name Analyst Code  Revenue - Broker Estimate
# 0            Bluestone, Jakob         653B                45448304000
# 1                 Lee, Andrew          FG3                45542645000
# 2             Grindle, Robert         4AIT                44651000000
# 3                Delfas, Nick         6VB2                44631580000
# 4              Dattani, Akhil         3MBD                44975000000
# 5           Deuscher, Bettina         4O3B                44754580000
# 6           Adorisio, Ottavio         4978                45100000000
# 7             De Vita, Andrea         1ABC                44150000000
# 8         Murdock-Smith, Carl         7K6U                44863000000
# 9              Hodel, Michael         4LNP                45035000000
# 10                 Tang, Polo         4Y98                45082809000
# 11             Rumley, Adam M         61LF                45241316000
# 12            Funnell, Justin         87UJ                45168000000
# 13          Volkert, Matthias         3820                44500000000
# 14              Dellis, Jerry         4UPP                44700000000
# 15         Patrick, Maurice G         4UH7                45053000000
# 16      Iatrides, Alexandre D         5ZI2                40499000000
# 17            Wright, David A         6Z0Y                45647500000
# 18  Van Leijenhorst, Matthijs         64TX                44694000000
# 19            Beale, Andrew C         3ZWO                44443000000
# 20             Kelly, Emmet B         6YOF                44930304000
# 21              Karidis, John         7FS1                44796000000
# 22             McHugh, Samuel         776T                45399000000

# %% [markdown]
# <font color='blue'>
#
# ### - Expanded industry metrics - this time for Tech and Telecom - using Verizon. Note these expanded metrics will not be available for all geographies.</font>

# %%
df5, err =ek.get_data(['VZ'],['TR.Subscribers.date','TR.Subscribers','TR.SubscribersBrokerName',
                              'TR.NetSubscriberAdds.date','TR.NetSubscriberAdds','TR.NetSubscriberAddsBrokerName',
                              'TR.AvgRevPerUnitEstValue.date','TR.AvgRevPerUnitEstValue','TR.AvgRevPerUnitEstBrokerName',
                              'TR.ChurnpctEstValue.date','TR.ChurnpctEstValue','TR.ChurnpctEstBrokerName'],
                    {'Period':'FY1','SDate':'-200','EDate':'0','Frq':'D'})
df5.head()
# Out:
#   Instrument                  Date  \
# 0         VZ  2020-07-24T20:02:00Z
# 1         VZ  2020-08-19T06:37:00Z
# 2         VZ  2020-08-19T06:37:00Z
# 3         VZ  2020-08-19T06:37:00Z
# 4         VZ  2020-08-19T06:37:00Z
#
#    No. Of Subscribers / Users - Broker Estimate                  Broker Name  \
# 0                                     122369000                     JPMORGAN
# 1                                          <NA>               SCOTIABANK GBM
# 2                                     122136000         MOFFETTNATHANSON LLC
# 3                                          <NA>  ROBERT W. BAIRD & CO., INC.
# 4                                     122136000         MOFFETTNATHANSON LLC
#
#                    Date  Net Subscriber Additions - Broker Estimate  \
# 0  2020-04-26T18:44:00Z                                     2074000
# 1  2020-07-25T14:17:00Z                                     1419000
# 2  2020-07-25T14:17:00Z                                        <NA>
# 3  2020-07-27T07:01:00Z                                     5246000
# 4  2020-07-25T14:17:00Z                                        <NA>
#
#                    Broker Name                  Date  \
# 0  WELLS FARGO SECURITIES, LLC  2020-08-19T06:37:00Z
# 1          RBC CAPITAL MARKETS  2020-07-27T07:45:00Z
# 2                DEUTSCHE BANK  2020-08-19T06:37:00Z
# 3    GUGGENHEIM SECURITIES LLC  2020-08-19T06:37:00Z
# 4            TRUIST SECURITIES  2020-08-19T06:37:00Z
#
#    Avg Revenue Per Unit / User - Broker Estimate                  Broker Name  \
# 0                                            NaN  WELLS FARGO SECURITIES, LLC
# 1                                          42.23      OPPENHEIMER & CO., INC.
# 2                                            NaN                     JPMORGAN
# 3                                          44.88         MOFFETTNATHANSON LLC
# 4                                            NaN                     JPMORGAN
#
#                    Date  Churn Percentage - Broker Estimate  \
# 0  2020-07-27T01:06:00Z                                 NaN
# 1  2020-04-24T11:45:00Z                                1.40
# 2  2020-07-27T01:06:00Z                                 NaN
# 3  2020-08-19T06:37:00Z                                1.21
# 4  2020-01-30T19:22:00Z                                1.27
#
#                Broker Name
# 0                 JPMORGAN
# 1  OPPENHEIMER & CO., INC.
# 2        TRUIST SECURITIES
# 3     MOFFETTNATHANSON LLC
# 4           SCOTIABANK GBM

# %% [markdown]
# <font color='blue'>
#
# ### Consensus Estimates
#
# ### - With so many different analyst opinions - consensus estimates developed to capture mean of all analysts
#
# ### - Our I/B/E/S (Institutional Brokers Estimates System) is the industry standard, founded in 1976
#
# ### - Offers coverage for 22K active companies across 90 countries from over 18K analysts
#
# ### - Not all analysts report on all measures - so number of included estimates can vary across measure
#
# ### - Some estimates are not included due to staleness
#
# ### - Can check variation estimates are by looking at Estimate High, Low and Median
#
# ### - Great thing is we can track these consensus estimates on a daily basis
#
# ### - Clustering / herd behaviour - can change these metrics rapidly in some cases in other cases its slow
#
# ### - To see the impact on shareprice of VOD.L - it is easy just to add a closing shareprice for the last 2000 days.</font>

# %%
df6, err =ek.get_data(['VOD.L'],['TR.RevenueMean(Period=FY1).calcdate',
                                 'TR.RevenueMean(Period=FY1)',
                                 'TR.RevenueNumIncEstimates(Period=FY1)',
                                 'TR.GrossIncomeMean(Period=FY1)',
                                 'TR.GrossIncomeNumIncEstimates(Period=FY1)',
                                 'TR.PreTaxProfitMean(Period=FY1)',
                                 'TR.PreTaxProfitNumIncEstimates(Period=FY1)',
                                 'TR.NetProfitMean(Period=FY1)',
                                 'TR.NetProfitNumIncEstimates(Period=FY1)',
                                 'TR.EPSMean(Period=FY1)',
                                 'TR.EPSNumIncEstimates(Period=FY1)',
                                 'TR.DPSMean(Period=FY1)',
                                 'TR.DPSNumIncEstimates(Period=FY1)',
                                 'TR.CLOSEPRICE(Adjusted=1)'],
                                 {'SDate':'-2000','EDate':'0', 'Frq':'D'})
                      
df6.index = pd.to_datetime(df6['Calc Date'])
df6
# Out:
#            Instrument   Calc Date  Revenue - Mean  \
# Calc Date
# 2013-07-18      VOD.L  2013-07-18     51903286170
# 2013-07-19      VOD.L  2013-07-19     51795907820
# 2013-07-22      VOD.L  2013-07-22     51809611380
# 2013-07-23      VOD.L  2013-07-23     51809611380
# 2013-07-24      VOD.L  2013-07-24     51946862980
# ...               ...         ...             ...
# 2021-06-10      VOD.L  2021-06-10     44945729000
# 2021-06-11      VOD.L  2021-06-11     44945729000
# 2021-06-14      VOD.L  2021-06-14     44945729000
# 2021-06-15      VOD.L  2021-06-15     44945729000
# 2021-06-16      VOD.L  2021-06-16     44945729000
#
#             Revenue - Number of Included Estimates  Gross Income - Mean  \
# Calc Date
# 2013-07-18                                      27                 <NA>
# 2013-07-19                                      27                 <NA>
# 2013-07-22                                      27          16155828620
# 2013-07-23                                      27          16155828620
# 2013-07-24                                      27          16155828620
# ...                                            ...                  ...
# 2021-06-10                                      22          14983000000
# 2021-06-11                                      22          14983000000
# 2021-06-14                                      22          14983000000
# 2021-06-15                                      22          14983000000
# 2021-06-16                                      22          14983000000
#
#             Gross Income - Number of Included Estimates  \
# Calc Date
# 2013-07-18                                         <NA>
# 2013-07-19                                         <NA>
# 2013-07-22                                            1
# 2013-07-23                                            1
# 2013-07-24                                            1
# ...                                                 ...
# 2021-06-10                                            1
# 2021-06-11                                            1
# 2021-06-14                                            1
# 2021-06-15                                            1
# 2021-06-16                                            1
#
#             Pre-Tax Profit - Mean  \
# Calc Date
# 2013-07-18            12555456840
# 2013-07-19            12489963540
# 2013-07-22            12494140500
# 2013-07-23            12494140500
# 2013-07-24            12522680530
# ...                           ...
# 2021-06-10             5010191560
# 2021-06-11             5010191560
# 2021-06-14             5010191560
# 2021-06-15             5010191560
# 2021-06-16             5010191560
#
#             Pre-Tax Profit - Number of Included Estimates  Net Income - Mean  \
# Calc Date
# 2013-07-18                                             22         9057185070
# 2013-07-19                                             22         8986446550
# 2013-07-22                                             22         9010753460
# 2013-07-23                                             22         9010753460
# 2013-07-24                                             22         9031506860
# ...                                                   ...                ...
# 2021-06-10                                             18         2872505190
# 2021-06-11                                             18         2872505190
# 2021-06-14                                             18         2872505190
# 2021-06-15                                             18         2872505190
# 2021-06-16                                             18         2872505190
#
#             Net Income - Number of Included Estimates  \
# Calc Date
# 2013-07-18                                         23
# 2013-07-19                                         23
# 2013-07-22                                         23
# 2013-07-23                                         23
# 2013-07-24                                         23
# ...                                               ...
# 2021-06-10                                         16
# 2021-06-11                                         16
# 2021-06-14                                         16
# 2021-06-15                                         16
# 2021-06-16                                         16
#
#             Earnings Per Share - Mean  \
# Calc Date
# 2013-07-18                    0.33761
# 2013-07-19                    0.33615
# 2013-07-22                    0.33770
# 2013-07-23                    0.33770
# 2013-07-24                    0.33853
# ...                               ...
# 2021-06-10                    0.09986
# 2021-06-11                    0.09986
# 2021-06-14                    0.09986
# 2021-06-15                    0.09986
# 2021-06-16                    0.09986
#
#             Earnings Per Share - Number of Included Estimates  \
# Calc Date
# 2013-07-18                                                 30
# 2013-07-19                                                 30
# 2013-07-22                                                 30
# 2013-07-23                                                 30
# 2013-07-24                                                 30
# ...                                                       ...
# 2021-06-10                                                 21
# 2021-06-11                                                 21
# 2021-06-14                                                 21
# 2021-06-15                                                 21
# 2021-06-16                                                 21
#
#             Dividend Per Share - Mean  \
# Calc Date
# 2013-07-18                    0.21906
# 2013-07-19                    0.21954
# 2013-07-22                    0.21476
# 2013-07-23                    0.21476
# 2013-07-24                    0.21476
# ...                               ...
# 2021-06-10                    0.09048
# 2021-06-11                    0.09048
# 2021-06-14                    0.09048
# 2021-06-15                    0.09048
# 2021-06-16                    0.09048
#
#             Dividend Per Share - Number of Included Estimates  Close Price
# Calc Date
# 2013-07-18                                                 29   196.115750
# 2013-07-19                                                 29   198.678015
# 2013-07-22                                                 28   198.831751
# 2013-07-23                                                 28   197.704354
# 2013-07-24                                                 28   198.421788
# ...                                                       ...          ...
# 2021-06-10                                                 23   129.800000
# 2021-06-11                                                 23   129.840000
# 2021-06-14                                                 23   130.000000
# 2021-06-15                                                 23   132.000000
# 2021-06-16                                                 23   130.160000
#
# [2001 rows x 15 columns]

# %% [markdown]
# <font color='blue'>
#
# ### - Easy to visualise any of these components impacts on shareprice</font>

# %%
df6[['Revenue - Mean','Close Price']].plot(subplots=True, figsize=(12,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe2c180e3c8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fe2c1378550>],
#       dtype=object)

# %%
df6[['Revenue - Mean','Close Price']].corr()
# Out:
#                 Revenue - Mean  Close Price
# Revenue - Mean        1.000000     0.785957
# Close Price           0.785957     1.000000

# %% [markdown]
# <font color='blue'>
#
# ### Starmine SmartEstimates
#
# ### - Go a step further by trying to weight more successful (in terms of accuracy) analyst opinions more highly
#
# ### - More weight is also given to more recent updates whilst those that are stale are completely dropped
#
# ### - Lots of papers written about validity and transparency of Starmine SmartEstimates
#
# ### - Lets get a selection of these SmartEstimates for 200 days and chart</font>

# %%
df7, err =ek.get_data(['VOD.L'],['TR.RevenueMean(Period=FY1).date',
                                 'TR.RevenueSmartEst(Period=FY1)',
                                 'TR.RevenueSENumIncEst(Period=FY1)',
                                 'TR.GrossIncomeSmartEst(Period=FY1)',
                                 'TR.GrossIncomeSENumIncEst(Period=FY1)',
                                 'TR.PreTaxProfitSmartEst(Period=FY1)',
                                 'TR.PreTaxProfitSENumIncEst(Period=FY1)',
                                 'TR.NetprofitSmartEst(Period=FY1)',
                                 'TR.NetProfitSENumIncEst(Period=FY1)',
# 2021-06-09 00:00:00+00:00                                                 10
# 2021-06-09 00:00:00+00:00                                                 10
# 2021-06-09 00:00:00+00:00                                                 10
# 2021-06-09 00:00:00+00:00                                                 10
# 2021-06-09 00:00:00+00:00                                                 10
#
#                            Dividend Per Share - SmartEstimate®  \
# Date
# 2020-07-31 00:00:00+00:00                              0.08902
# 2020-07-31 00:00:00+00:00                              0.08902
# 2020-07-31 00:00:00+00:00                              0.08902
# 2020-07-31 00:00:00+00:00                              0.08902
# 2020-07-31 00:00:00+00:00                              0.08902
# ...                                                        ...
# 2021-06-09 00:00:00+00:00                              0.09040
# 2021-06-09 00:00:00+00:00                              0.09040
# 2021-06-09 00:00:00+00:00                              0.09040
# 2021-06-09 00:00:00+00:00                              0.09040
# 2021-06-09 00:00:00+00:00                              0.09040
#
#                            Dividend Per Share - SmartEstimate Num of Included Estimates  \
# Date
# 2020-07-31 00:00:00+00:00                                                  7
# 2020-07-31 00:00:00+00:00                                                  7
# 2020-07-31 00:00:00+00:00                                                  7
# 2020-07-31 00:00:00+00:00                                                  7
# 2020-07-31 00:00:00+00:00                                                  7
# ...                                                                      ...
# 2021-06-09 00:00:00+00:00                                                 10
# 2021-06-09 00:00:00+00:00                                                 10
# 2021-06-09 00:00:00+00:00                                                 10
# 2021-06-09 00:00:00+00:00                                                 10
# 2021-06-09 00:00:00+00:00                                                 10
#
#                            Close Price
# Date
# 2020-07-31 00:00:00+00:00       111.44
# 2020-07-31 00:00:00+00:00       107.16
# 2020-07-31 00:00:00+00:00       108.54
# 2020-07-31 00:00:00+00:00       107.70
# 2020-07-31 00:00:00+00:00       105.26
# ...                                ...
# 2021-06-09 00:00:00+00:00       129.80
# 2021-06-09 00:00:00+00:00       129.84
# 2021-06-09 00:00:00+00:00       130.00
# 2021-06-09 00:00:00+00:00       132.00
# 2021-06-09 00:00:00+00:00       130.16
#
# [201 rows x 15 columns]

# %%
df7[['Net Income - SmartEstimate®','Close Price']].plot(subplots=True,figsize=(12,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe2c1a91fd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fe2c1a72128>],
#       dtype=object)

# %%
df7[['Net Income - SmartEstimate®','Close Price']].corr()
# Out:
#                              Net Income - SmartEstimate®  Close Price
# Net Income - SmartEstimate®                     1.000000     0.681725
# Close Price                                     0.681725     1.000000

# %% [markdown]
# ## Discounted Cashflow
# <font color='blue'>
#
# ### - Many ways to approach this sort of valuation task as evidenced by number of textbooks on the subject
#
# ### - Instead of us forecasting free cashflow ourselves - we use I/B/E/S consensus - typically these go out 4 years or so
#
# ### - After this period, forecasting becomes more challenging - but we need to capture what is known as a terminal value for the remaining cashflows based on some exit multiple
#
# ### - We take the most recent EV / FCF multiple and assign that to our last forecasted cashflow number to get our terminal value
#
# ### - So lets get some data, first some stock-type data</font>

# %%
df8,err = ek.get_data('VOD.L',['TR.F.DebtTot','TR.WACC','TR.F.ComShrOutsTot(Period=FY0)', 'TR.EVtoFCFSmartEst(Period=FY1)'])
df8
# Out:
#   Instrument  Debt - Total  Weighted Average Cost of Capital, (%)  \
# 0      VOD.L   67760000000                               4.335264
#
#    Common Shares - Outstanding - Total  EV / Free Cash Flow (SmartEstimate ®)
# 0                          28224193469                              21.979102

# %% [markdown]
# <font color='blue'>
#
# ### - Next we will get our IBES consensus free cashflow forecasts going out 4 fiscal years. I also include the most recent actual value at the start. </font>

# %%
fcf,err = ek.get_data('VOD.L',['TR.FCFMean(Period=FY0)','TR.FCFMean(Period=FY1)','TR.FCFMean(Period=FY2)',
                     'TR.FCFMean(Period=FY3)','TR.FCFMean(Period=FY4)'])
fcf.columns =['RIC','FCF-FY0','FCF-FY1','FCF-FY2','FCF-FY3','FCF-FY4']
fcf
# Out:
#      RIC     FCF-FY0     FCF-FY1     FCF-FY2     FCF-FY3     FCF-FY4
# 0  VOD.L  4747681060  4639847320  5089980000  5279681900  5859000000

# %% [markdown]
# <font color='blue'>
#
# ### - Next, calculate the net present value (NPV) of these cashflows using WACC as the discount rate.</font>

# %%
dfcf = np.npv(df8['Weighted Average Cost of Capital, (%)'].values,fcf.iloc[0,2:5].values.tolist())
dfcf
# Out:
# 5779352764.736227

# %% [markdown]
# <font color='blue'>
#
# ### - Now calculate our terminal value using the exit multiple we identified - in this case Enterprise Value / Free Cashflow multiple, and apply this to the last Free Cashflow forecast (FY4).</font>

# %%
tv_exit = df8['EV / Free Cash Flow (SmartEstimate ®)'] * fcf.iloc[0][5]
tv_exit
# Out:
# 0    1.287756e+11
# Name: EV / Free Cash Flow (SmartEstimate ®), dtype: float64

# %% [markdown]
# <font color='blue'>
#
# ### - We now set our flow value to be the sum of our discounted cashflow plus our terminal value. </font>

# %%
flo_val = dfcf + tv_exit
flo_val
# Out:
# 0    1.345549e+11
# Name: EV / Free Cash Flow (SmartEstimate ®), dtype: float64

# %% [markdown]
# <font color='blue'>
#
# ### - Subtract the debt portion from the enterprise value so we are left with our Equity portion - which we can then divide by shares outstanding to get our valuation per share.</font>

# %%
model_price = (flo_val - df8['Debt - Total'])/ df8['Common Shares - Outstanding - Total']
model_price
# Out:
# 0    2.366584
# dtype: float64

# %% [markdown]
# <font color='blue'>
#
# ### - As this is a UK share we need to multiply the equity value (which is in pounds) to pence so we can compare it to the quoted shareprice.</font>

# %%
model_price*100
# Out:
# 0    236.658356
# dtype: float64

# %% [markdown]
# <font color='blue'>
#
# ### - Now we can just compare it to the most recent closing price. </font>

# %%
df9, err = ek.get_data('VOD.L','CF_CLOSE')
df9
# Out:
#   Instrument  CF_CLOSE
# 0      VOD.L    130.16

# %% [markdown]
# ## Peer Group Comparison
# <font color='blue'>
#
# ### - Eikon Data API provide neat Peers function - retrieve list of Global Peer RICs
#
# ### - Easy to scale an intrinsic valuation to a relative valuation or competitor analysis
#
# ### - We will use our previous DCF - but you can of course replace or add your own measures such as PER, PCF, PTS, EV/Ebitda, Dividend Yield etc
#
# ### - When scaling you may need to handle missing data etc so dealing with exceptions is part of process - however I just drop any problem candidates as we have enough peers
#
# ### - Cautionary note: no two companies are identical, differences in balance sheet structures, asset holdings, efficiencies, innovation, performance stability and many other factors all play major roles in divergent outcomes of companies. Also different economic phases can effect companies differently eg NIRP/ZIRP could keep zombie companies alive for longer than normal interest rate environments would tolerate. DCF is just one tool in our armoury.
#
# ### - Get all data we need for target and its peers -  I also drop any peers with NAs </font>

# %%
ric = 'VOD.L'
peers, err = ek.get_data([ric,"Peers("+ric+")"],fields=['TR.CompanyName','TR.ExchangeCountry','TR.PeersRank',
                                                    'TR.F.DebtTot','TR.WACC','TR.F.ComShrOutsTot(Period=FY0)', 
                                                    'TR.EVtoFCFSmartEst(Period=FY1)','TR.FCFMean(Period=FY0)',
                                                    'TR.FCFMean(Period=FY1)','TR.FCFMean(Period=FY2)',
                                                    'TR.FCFMean(Period=FY3)','TR.FCFMean(Period=FY4)','TR.PRICECLOSE'])
peers.columns =['RIC','Name','Country','Peers Rank','Debt - Total','WACC %','Shs Out','EV/FCF','FCF-FY0','FCF-FY1','FCF-FY2','FCF-FY3','FCF-FY4','Close Price']
peers['EV/FCF'] = peers['EV/FCF'].astype(float)
peers['Peers Rank'][0] = 0
peers.dropna(axis=0, how='any',inplace=True)
peers.reset_index(drop=True, inplace=True)
peers
# Out:
#          RIC                                         Name  \
# 0      VOD.L                           Vodafone Group PLC
# 1       BT.L                                 BT Group PLC
# 2   DTEGn.DE                          Deutsche Telekom AG
# 3    ORAN.PA                                    Orange SA
# 4     TEF.MC                                Telefonica SA
# 5    O2Dn.DE            Telefonica Deutschland Holding AG
# 6    BOUY.PA                                  Bouygues SA
# 7    TLIT.MI                           Telecom Italia SpA
# 8   LBTYA.OQ                           Liberty Global PLC
# 9     SCMN.S                                  Swisscom AG
# 10    ILD.PA                                     Iliad SA
# 11    KPN.AS                           Koninklijke KPN NV
# 12  TELIA.ST                             Telia Company AB
# 13   UTDI.DE                           United Internet AG
# 14   PROX.BR                                  Proximus NV
# 15    1U1.DE                                       1&1 AG
# 16   TNET.BR                     Telenet Group Holding NV
# 17  ELISA.HE                                    Elisa Oyj
# 18   INWT.MI         Infrastrutture Wireless Italiane SpA
# 19    TEL.OL                                  Telenor ASA
# 20   TELA.VI                           Telekom Austria AG
# 21  TEL2b.ST                                     Tele2 AB
# 22   OBEL.BR                            Orange Belgium SA
# 23    VIV.PA                                   Vivendi SE
# 24   OTEr.AT  Hellenic Telecommunications Organization SA
# 25  FNTGn.DE                                   freenet AG
# 26    GAMA.L                     Gamma Communications PLC
# 27   RWAY.MI                                  Rai Way SpA
# 28   SGEF.PA                                     Vinci SA
# 29   SGOB.PA                 Compagnie de Saint Gobain SA
# 30  ERICb.ST              Telefonaktiebolaget LM Ericsson
# 31  NOKIA.HE                                    Nokia Oyj
# 32   TMUS.OQ                              T-Mobile US Inc
# 33  IFXGn.DE                     Infineon Technologies AG
# 34    STM.PA                        STMicroelectronics NV
# 35    ATUS.N                               Altice USA Inc
# 36    VODJ.J                            Vodacom Group Ltd
# 37    GEBN.S                                   Geberit AG
# 38  SESFd.PA                                       SES SA
# 39    ETL.PA                   Eutelsat Communications SA
# 40   EKTL.MC                                 Euskaltel SA
# 41     CRH.I                                      CRH PLC
# 42      VZ.N                   Verizon Communications Inc
# 43       T.N                                     AT&T Inc
# 44    SSAq.L                              AFK Sistema PAO
# 45    VON.AS                                     VEON Ltd
# 32   14362914910   16783500000     144.9100
# 33    1482898290    1553750000      33.9600
# 34    1400828270    1944500000      31.5000
# 35    2000532000    2281510780      33.7600
# 36   21100500000   20951000000   13549.0000
# 37     748797270     778066670     675.8000
# 38     685893250     324530000       6.6600
# 39     451064000     446855000      10.2150
# 40     111890000     169000000      10.9600
# 41    3020989440    3068939450      42.5900
# 42   19205769100   22992714290      56.6400
# 43   23564000000   24388400000      29.0600
# 44  171401000000  172459500000       8.7800
# 45    1008120000     933145000       1.4020

# %% [markdown]
# <font color='blue'>
#
# ### - Conduct DCF for all companies and compare closing price with model price</font>

# %%
peers['m_price']= np.nan
peers['method'] = np.nan
peers['prem/disc'] = np.nan

for i, peer in enumerate(peers['RIC']):
    multiple = peers.iloc[i][7]
    
    for col in range(12,9,-1):
        if pd.isnull(peers.iloc[i][col]):
            pass
        else:
            last = col
            break
    
    dfcf = np.npv(peers.iloc[i][5],peers.iloc[i,9:last].tolist())
    if not pd.isna(dfcf):
        if dfcf>0:
            if pd.isnull(multiple) or multiple == "NaN":
                tv_exit  =  (peers.iloc[i][last] * (1 + 0.1))  /  ((peers.iloc[i]['WACC %']) - 1)     
                peers['method'][i] = 'perpetual growth'
            elif peers.iloc[i][last] <0:
                tv_exit = multiple * peers.iloc[i,9:last].mean()
                peers['method'][i] = 'multiple - fcfAvg'
            else:
                tv_exit = multiple * peers.iloc[i][last]
                peers['method'][i] = 'multiple'
            
            flo_val = dfcf + tv_exit
            model_price = (flo_val - peers.iloc[i]['Debt - Total'])/ peers.iloc[i]['Shs Out']
            peers['m_price'][i] = model_price
            
            if peers.iloc[i][2] == 'United Kingdom' or peers.iloc[i][2] == 'South Africa':
                peers['m_price'][i] = peers['m_price'][i]*100
            
            if not pd.isnull(peers.iloc[i]['Close Price']):
                if not pd.isnull(peers.iloc[i]['m_price']):
                    peers['prem/disc'][i] = (peers.iloc[i]['Close Price'] / peers.iloc[i]['m_price']-1) *100
    else:
        peers.iloc[i]['m_price'] = np.nan

peers
# Out:
#          RIC                                         Name  \
# 0      VOD.L                           Vodafone Group PLC
# 1       BT.L                                 BT Group PLC
# 2   DTEGn.DE                          Deutsche Telekom AG
# 3    ORAN.PA                                    Orange SA
# 4     TEF.MC                                Telefonica SA
# 5    O2Dn.DE            Telefonica Deutschland Holding AG
# 6    BOUY.PA                                  Bouygues SA
# 7    TLIT.MI                           Telecom Italia SpA
# 8   LBTYA.OQ                           Liberty Global PLC
# 9     SCMN.S                                  Swisscom AG
# 10    ILD.PA                                     Iliad SA
# 11    KPN.AS                           Koninklijke KPN NV
# 12  TELIA.ST                             Telia Company AB
# 13   UTDI.DE                           United Internet AG
# 14   PROX.BR                                  Proximus NV
# 15    1U1.DE                                       1&1 AG
# 16   TNET.BR                     Telenet Group Holding NV
# 17  ELISA.HE                                    Elisa Oyj
# 18   INWT.MI         Infrastrutture Wireless Italiane SpA
# 19    TEL.OL                                  Telenor ASA
# 20   TELA.VI                           Telekom Austria AG
# 21  TEL2b.ST                                     Tele2 AB
# 31 -33.627056
# 32 -74.847949
# 33 -22.222330
# 34 -78.605262
# 35 -50.765938
# 36 -20.322791
# 37 -15.954565
# 38 -36.729080
# 39  -1.987123
# 40 -68.254292
# 41 -28.117756
# 42 -39.684122
# 43 -16.130838
# 44 -99.941601
# 45 -60.771695

# %% [markdown]
# ## Relative Valuation
# <font color='blue'>
#
# ### - Now we can place VOD.L in a DCF relative valuation space amongst its peers
#
# ### - Can easily adapt to all manner of factors and metrics
#
# ### - Outlier handling important - xlim or ylim parameters useful or explicit exclusion may also be required - examples of both
#
# ### - Linear regression up first </font>

# %%
ax1 = peers.plot.scatter(x='prem/disc',y='EV/FCF',figsize=(15,10))

for i, ric in enumerate(peers['RIC']):
    if not pd.isnull(peers['prem/disc'][i]):
        if not pd.isnull(peers['EV/FCF'][i]):
            ax1.set_ylim(10,55)
            ax1.set_xlim(-100, 100)
            if not ric=='ILD.PA':
                ax1.text(x=peers['prem/disc'][i]+0.3,y=peers['EV/FCF'][i]+0.3,s=peers['RIC'][i])

X, Y = peers['prem/disc'].values.reshape(-1,1), peers['EV/FCF'].values.reshape(-1,1)
ax1.plot(X, LinearRegression().fit(X, Y).predict(X))

# %% [markdown]
# ## Clustering
# <font color='blue'>
#
# ### - Try to extend our relative valuation study to group similar companies into clusters. We saw previously there seemed to be a steep negative relationship between our two variables
#
# ### - However are there perhaps more useful ways of classifying this distribution eg Do companies that have very high EV/FCF multiples really belong in the same group as those that have low or more reasonable EV/FCF?
#
# ### - Thankfully yes - here we use an unsupervised algorithm - the algo generates the group labels from the observed data
#
# ### - Many ways of doing this - we look at 2 - KMeans clustering and Gaussian Mixture Models, popular in the literature.
#
# ### - I am interested in classifying the bulk of observations so I more formally remove outliers </font>

# %%
exoutlier = peers[(peers['prem/disc'] < 50) & (peers['EV/FCF'] < 55)]
X = exoutlier[['prem/disc','EV/FCF']].values

# %% [markdown]
# <font color='blue'>
#
# ### KMeans Clustering
#
# ### - Determine optimal amount of clusters using elbow chart. Conduct KMeans 10 times and graph the intertia_ property ==> tells us 2-3 clusters is optimal
#
# ### - Use n_clusters = 3 to generate classification and plot it </font>

# %%
inertia = []
K = range(1,10)
for k in K:
    km = KMeans(n_clusters=k)
    km.fit(X)
    inertia.append(km.inertia_)

plt.plot(K, inertia, 'bx-')

# %%
km = KMeans(n_clusters=3)
km.fit(X)
pred =km.predict(X)
clusters = unique(pred)
for cluster in clusters:
    row = where(pred == cluster)
    plt.scatter(X[row, 0], X[row, 1])
plt.show()

# %% [markdown]
# <font color='blue'>
#
# ### Gaussian Mixture Models
#
# ### - Same way use n_components=3 and generate cluster groupings</font>

# %%
model = GaussianMixture(n_components=3)
model.fit(X)
pred = model.predict(X)
clusters = unique(pred)
for cluster in clusters:
    row = where(pred == cluster)
    plt.scatter(X[row, 0], X[row, 1])
plt.show()

# %% [markdown]
# <font color='blue'>
#
# ### - In this case simple linear regression works rather well
#
# ### - Some merit in groupings suggested by KM and GMM
#
# ### - Which to use could depend on use case but can provide further information for your quantamental analysis</font>
